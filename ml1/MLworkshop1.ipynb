# %% [markdown]
# # MLworkshop1 - linear regression

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
houses = pd.read_csv('./kc_house_data.csv')
print(houses.columns)
X = houses[['bedrooms']]
X1 = houses[['sqft_living']]
Y = houses['price']
plt.figure(figsize=(30,20))
plt.scatter(X1, Y)
plt.show()
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
def predict(weights, feature_vector):
    pass

# %%
def RSS(weights, feature_matrix, target):
    pass

# %%
def gradient_descent(initial_weights, feature_matrix, target, alpha):
    pass

# %%
def closed_form_solution(feature_matrix, weights):
    pass

# %%
from sklearn import datasets
data = datasets.load_boston()

# %%
X = data.data
Y = data.target
print(X.shape, Y.shape)
#plt.scatter(X[:,4], Y)
plt.show()
# Out:
# (506, 13) (506,)
